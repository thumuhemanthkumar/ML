# %%
# 1.Import pandas
import pandas as pd
from google.colab import files

# 2.Upload the CSV file
uploaded = files.upload()
filename = next(iter(uploaded))

# 3.Load the dataset
df = pd.read_csv(filename)

print("Loaded file:", filename)
# Out:
#      <input type="file" id="files-98ac0d7d-78ab-4207-8a67-f565c2f29271" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98ac0d7d-78ab-4207-8a67-f565c2f29271">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 4.Display first 5 rows
print("First Five Rows:")
print(df.head())

# 5.Check dataset shape
print("\nDataset Shape:")
print(df.shape)

# 6.Check column names
print("\nColumn Names:")
print(df.columns)

# 7.Check data types
print("\nData Types:")
print(df.dtypes)

# 8.Display dataset information
print("\nDataset Information:")
df.info()

# 9.View statistical summary
print("\nStatistical Summary:")
print(df.describe())

# 10.Check missing values
print("\nMissing Values:")
print(df.isnull().sum())

# 11.Check duplicate rows
print("\nDuplicate Rows:")
print(df.duplicated().sum())

# 12.Study placement classes
print("\nPlacement Class Distribution:")
print(df["PlacementStatus"].value_counts())

# Calculate class percentages
print("\nPlacement Class Percentage:")
print(df["PlacementStatus"].value_counts(normalize=True) * 100)
# Out:
# First Five Rows:
#    StudentID  Gender       City CollegeTier Stream Specialisation Hostel  \
# 0          1    Male  Ahmedabad       Tier2    ECE     Networking     No
# 1          2  Female     Mumbai       Tier2    ECE    DataScience    Yes
# 2          3    Male    Kolkata       Tier2     IT    DataScience    Yes
# 3          4    Male     Jaipur       Tier1     CS             AI     No
# 4          5    Male       Pune       Tier2     IT    DataScience    Yes
#
#   HistoryOfBacklogs  SGPA_Sem1  SGPA_Sem2  ...  Publications  \
# 0                No       6.02       6.54  ...             0
# 1               Yes       5.84       5.12  ...             0
# 2                No       4.91       5.29  ...             0
# 3                No       7.67       8.03  ...             0
# 4                No       8.14       8.97  ...             1
#
#    AptitudeTestScore  SoftSkillsRating  CodingTestScore  MockInterviewScore  \
# ...
